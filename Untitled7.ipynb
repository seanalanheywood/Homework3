# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline
def assignment3():
    df = (pd.read_csv('iris.txt'))
    head = df.head()
    tail = df.tail()
    stat = df.describe(include = ['object', 'float'])
    df.plot.box()
    df.plot.line()
    df.plot.hist()
    print(head)
    print(tail)
    print(stat)
assignment3()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#         SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# count    150.000000  150.000000   150.000000  150.000000              150
# ...

# %% [markdown]
# Analysis write up for non-grouped questions
#
# 1. Read iris.txt into a data frame.
#       The data is a file with comma separated values. It contains integers, floats and strings. It appears to be broken up
#       by three species and four categories that describe the Iris"""
# 2. Explore the data.
#   1. Printing the head of the dataset displays the first five lines in the file we are analyzing.
#   2. Printing the tail of the dataset displays the last five lines in the file we are analyzing.
#   3. Once we printed the summary statistics, we are able to interpret the data in the iris.txt.
#      Because we are printing numeric and categorical data, NaN is displayed for non-numeric data.
#      For descriptive statistics, it makes sense that we wouldn't have any data displayed in the category column
#      because this is dealing with strings as opposed to numbers.
#   4. Next we generate the box plots. The box plots show that PetalLength has the widest range of outcomes and is skewed
#      due to the outlier in the data. PetalWidth is also skewed but not nearly as much as PetalLength.
#   5. Next we generate a line plot. PetalLength and width again share a similar pattern with the numbers being displayed
#      in the graph. There is a sense that there is correlation among these two variables. It's tough to infer much about the
#      other two variables other than they are both relatively steady as far as the numbers in the file. They don't vary much
#      from the median.
#   6. Finally, we generate a histogram of the dataset. By far, the most popular values are between 2.5 - 3.1 for the
#      PetalWidth size. The large concentration doesn't surprise me because it had the smallest range of values in
#      the box plot and did not have any major outliers. PetalWidth also didn't have too many outliers which is why the
#      histogram is relatively flat for that variable.

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline
def assignment3():
    df = (pd.read_csv('iris.txt').groupby('Species'))
    stat = df.describe()
    df.plot.box()
    print(stat)
assignment3()
# Out:
#                        PetalLength  PetalWidth  SepalLength  SepalWidth
# Species
# Iris-setosa     count    50.000000   50.000000    50.000000   50.000000
#                 mean      1.464000    0.244000     5.006000    3.418000
#                 std       0.173511    0.107210     0.352490    0.381024
#                 min       1.000000    0.100000     4.300000    2.300000
#                 25%       1.400000    0.200000     4.800000    3.125000
#                 50%       1.500000    0.200000     5.000000    3.400000
#                 75%       1.575000    0.300000     5.200000    3.675000
#                 max       1.900000    0.600000     5.800000    4.400000
# Iris-versicolor count    50.000000   50.000000    50.000000   50.000000
#                 mean      4.260000    1.326000     5.936000    2.770000
#                 std       0.469911    0.197753     0.516171    0.313798
#                 min       3.000000    1.000000     4.900000    2.000000
# ...

# %% [markdown]
# Analysis write up for grouped questions
#
# 3. Group the data on the Species column and explore the partitioned dataset
#   1. Printing the summary statistics in this part of the assignment proves to be more useful when analyzing the data.
#      The first thing I noticed was that each species had 50 entries as determined by the count outcome in the
#      descriptive statistics. This tells us that we don't have to weight any of the species differenty based on more
#      or less data on a given Iris. The mean tells use that the Virginica species is the largest among the three species.
#   2. This time, we have box plots for each species. The box plots show us a couple things about the range of values
#      entered for each species and the corresponding categories. The Setosa species has the most narrow range of entries
#      followed by the other two. The other two species are very close as far as the distribution of the numbers per
#      category.

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline
def assignment3():
   scatter_matrix(pd.read_csv('iris.txt'))
assignment3()

# %% [markdown]
# Analysis for scatter matrix
# 3. This scatter matrix looks to be a combination of scatterplots and bar graphs that are displayed diagonally.
#    This gives us a great illustration on how the entries are being distributed in the Iris file. SepalLength and
#    SepalWidth seem to have a more normal distribution while the PetalLength and PetalWidth have a similar skewed
#    distribution.

# %% [markdown]
# Answer to the analysis
#
# 4. The mean of the species looks to be one reliable variable to look at when predicting the species. In 3 of the 4
#    categories, the largest mean happened to be the Virginica species. One can make the assumption that the larger
#    the SepalLength, SepalWidth, and PedalLength, the more likely the species is to be the Virginica. On the otherhand,
#    the smaller these variables are, the more likely the species is to be Setosa.
#
#    However, another reliable way is analyze the PedalWidth size because they have the smallest range of outcomes
#    based on the box plots. It's pretty easy to tell when a flower is a Setosa based on this size. The range is much
#    smaller and closer to the median than the other two species. The median on the Virginica is much higher than the
#    other two species as well.
